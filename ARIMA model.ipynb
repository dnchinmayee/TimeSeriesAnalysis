# %% [markdown]
# # check for stationary and seasonlaity
# if data is stationary then Time series does not exhibit any trens or seasonality
# if data is Seasonal then it is non stationary i.e it shows trend,seasonality

# %% [markdown]
# # AR model
# when I=MA=0 i,e AR ans MA components are zero, we do calculate the AR model.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:/Users/User/Downloads/UDEMY_TSA_FINAL/UDEMY_TSA_FINAL/Data/samples.csv", parse_dates=True,index_col=0)

# %%
df
# Out:
#              a   b      c   d
# 1950-01-01  36  27      0  67
# 1950-02-01  58  22      3  31
# 1950-03-01  61  17      5  67
# 1950-04-01  37  15      8  47
# 1950-05-01  66  13      8  62
# ...         ..  ..    ...  ..
# 1959-08-01  49  73   9338  58
# 1959-09-01  41  77   9502  38
# 1959-10-01  64  70   9667  42
# 1959-11-01  37  87   9833  62
# 1959-12-01  38  73  10000  50
#
# [120 rows x 4 columns]

# %%
df['a'].plot()
# Out:
# <AxesSubplot:>

# %%
df['b'].plot()
# Out:
# <AxesSubplot:>

# %%
from statsmodels.tsa.statespace.tools import diff

# %%
df['b']
# Out:
# 1950-01-01    27
# 1950-02-01    22
# 1950-03-01    17
# 1950-04-01    15
# 1950-05-01    13
#               ..
# 1959-08-01    73
# 1959-09-01    77
# 1959-10-01    70
# 1959-11-01    87
# 1959-12-01    73
# Name: b, Length: 120, dtype: int64

# %%
df['b'].shift(1)
# Out:
# 1950-01-01     NaN
# 1950-02-01    27.0
# 1950-03-01    22.0
# 1950-04-01    17.0
# 1950-05-01    15.0
#               ...
# 1959-08-01    70.0
# 1959-09-01    73.0
# 1959-10-01    77.0
# 1959-11-01    70.0
# 1959-12-01    87.0
# Name: b, Length: 120, dtype: float64

# %%
df['b']-df['b'].shift(1)
# Out:
# 1950-01-01     NaN
# 1950-02-01    -5.0
# 1950-03-01    -5.0
# 1950-04-01    -2.0
# 1950-05-01    -2.0
#               ...
# 1959-08-01     3.0
# 1959-09-01     4.0
# 1959-10-01    -7.0
# 1959-11-01    17.0
# 1959-12-01   -14.0
# Name: b, Length: 120, dtype: float64

# %%
diff(df['b'], k_diff=1).plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model becomes a Stationary model
