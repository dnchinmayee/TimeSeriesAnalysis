# %% [markdown]
# # This program shows the correlation between independent and dependent variables.
# We have used ACF and PACF to find the relation.

# %%
import numpy as np
import pandas as pd
from statsmodels.tsa.ar_model import AR,ARResults

# %%
df1 = pd.read_csv(r"C:/Users/User/Downloads/UDEMY_TSA_FINAL/UDEMY_TSA_FINAL/Data/airline_passengers.csv", parse_dates=True, index_col='Month')

# %%
df1
# Out:
#             PopEst
# DATE
# 2011-01-01  311037
# 2011-02-01  311189
# 2011-03-01  311351
# 2011-04-01  311522
# 2011-05-01  311699
# ...            ...
# 2018-08-01  327698
# 2018-09-01  327893
# 2018-10-01  328077
# 2018-11-01  328241
# 2018-12-01  328393
#
# [96 rows x 1 columns]

# %%
df2 = pd.read_csv(r"C:/Users/User/Downloads/UDEMY_TSA_FINAL/UDEMY_TSA_FINAL/Data/DailyTotalFemaleBirths.csv", index_col = 'Date',parse_dates=True)

# %%
df2
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %%
df2.plot()
#stationary data
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#fimd ACF function
from statsmodels.tsa.stattools import acf,pacf,pacf_yw,pacf_ols

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(df1['Thousands of Passengers'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
lag_plot(df2['Births'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
#check autocorrelation for seasonal data

# %%
plot_acf(df1, lags=40);

# %%
plot_acf(df1);

# %%
#chack Autocorrelation for Stationary data

# %%
plot_acf(df2, lags=40);

# %%
plot_pacf(df2, lags=40, title="daily female birth");
