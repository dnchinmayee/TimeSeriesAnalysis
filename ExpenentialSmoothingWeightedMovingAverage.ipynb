# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:/Users/User/Downloads/UDEMY_TSA_FINAL/UDEMY_TSA_FINAL/Data/airline_passengers.csv", index_col = 'Month',parse_dates=True)

# %%
df
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
df['Thousands of Passengers'].plot(figsize=(7,8))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
df.dropna()
# Out:
#             Thousands of Passengers
# Month
# 1949-01-01                      112
# 1949-02-01                      118
# 1949-03-01                      132
# 1949-04-01                      129
# 1949-05-01                      121
# ...                             ...
# 1960-08-01                      606
# 1960-09-01                      508
# 1960-10-01                      461
# 1960-11-01                      390
# 1960-12-01                      432
#
# [144 rows x 1 columns]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(df['Thousands of Passengers'], model='multiplicative')

# %%
result.resid
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
#               ..
# 1960-08-01   NaN
# 1960-09-01   NaN
# 1960-10-01   NaN
# 1960-11-01   NaN
# 1960-12-01   NaN
# Name: resid, Length: 144, dtype: float64

# %%
result.trend
# Out:
# Month
# 1949-01-01   NaN
# 1949-02-01   NaN
# 1949-03-01   NaN
# 1949-04-01   NaN
# 1949-05-01   NaN
#               ..
# 1960-08-01   NaN
# 1960-09-01   NaN
# 1960-10-01   NaN
# 1960-11-01   NaN
# 1960-12-01   NaN
# Name: trend, Length: 144, dtype: float64

# %%
result.seasonal
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
#                 ...
# 1960-08-01    1.219911
# 1960-09-01    1.060492
# 1960-10-01    0.921757
# 1960-11-01    0.801178
# 1960-12-01    0.898824
# Name: seasonal, Length: 144, dtype: float64

# %%
result.plot();

# %%
df['12_months_SMA'] = df['Thousands of Passengers'].rolling(window=12).mean()

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
#EMWA
#BECAUSE in SIMPLE MOVING average we have lags

# %%
df['EWMA_12']  = df['Thousands of Passengers'].ewm(span=12).mean()

# %%
df[['Thousands of Passengers','EWMA_12']].plot(figsize=(7,5));
